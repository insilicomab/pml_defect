# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pml_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pml_defect

# %%
# !pip install -q timm wandb pytorch-metric-learning[with-hooks] torchmetrics tensorboard
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 549 kB 35.4 MB/s
#      |████████████████████████████████| 1.9 MB 65.9 MB/s
#      |████████████████████████████████| 111 kB 92.5 MB/s
#      |████████████████████████████████| 512 kB 77.2 MB/s
#      |████████████████████████████████| 182 kB 97.1 MB/s
#      |████████████████████████████████| 173 kB 77.9 MB/s
#      |████████████████████████████████| 182 kB 80.7 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#      |████████████████████████████████| 168 kB 96.3 MB/s
#      |████████████████████████████████| 168 kB 87.3 MB/s
#      |████████████████████████████████| 166 kB 91.2 MB/s
#      |████████████████████████████████| 166 kB 114.2 MB/s
#      |████████████████████████████████| 162 kB 105.9 MB/s
#      |████████████████████████████████| 162 kB 90.4 MB/s
#      |████████████████████████████████| 158 kB 91.7 MB/s
#      |████████████████████████████████| 157 kB 106.9 MB/s
#      |████████████████████████████████| 157 kB 111.5 MB/s
#      |████████████████████████████████| 157 kB 104.3 MB/s
#      |████████████████████████████████| 157 kB 109.4 MB/s
#      |████████████████████████████████| 157 kB 87.1 MB/s
#      |████████████████████████████████| 157 kB 109.9 MB/s
#      |████████████████████████████████| 157 kB 111.0 MB/s
#      |████████████████████████████████| 156 kB 87.1 MB/s
#      |████████████████████████████████| 85.5 MB 1.1 MB/s
#   Building wheel for pathtools (setup.py) ... done
#      |████████████████████████████████| 153 kB 32.2 MB/s
#      |████████████████████████████████| 79 kB 9.8 MB/s
#      |████████████████████████████████| 117 kB 107.3 MB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python train.py
# Out:
# wandb: Currently logged in as: insilicomab. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.7
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab Notebooks/pml_defect/wandb/run-20221218_154557-1jxhrgsd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run blooming-plant-1
# wandb: ⭐️ View project at https://wandb.ai/insilicomab/pml-defect
# wandb: 🚀 View run at https://wandb.ai/insilicomab/pml-defect/runs/1jxhrgsd
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_base_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_base_1k_224_ema.pth
# 100% 47/47 [01:03<00:00,  1.35s/it]
# Epoch 1: train_loss = 19.17742156982422
# 100% 63/63 [00:19<00:00,  3.24it/s]
# Epoch 1: test_loss = 5.594365119934082
# 100% 6/6 [00:03<00:00,  1.52it/s]
# 100% 2/2 [00:01<00:00,  1.33it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.905, test_NMI = 0.560, test_AMI = 0.554, test_r_precision = 0.658, test_mean_average_precision_at_r = 0.531
# 100% 47/47 [00:17<00:00,  2.73it/s]
# Epoch 2: train_loss = 13.687861442565918
# 100% 63/63 [00:01<00:00, 48.67it/s]
# Epoch 2: test_loss = 0.01685674861073494
# 100% 6/6 [00:03<00:00,  1.51it/s]
# 100% 2/2 [00:01<00:00,  1.31it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.984, test_NMI = 0.895, test_AMI = 0.894, test_r_precision = 0.907, test_mean_average_precision_at_r = 0.882
# 100% 47/47 [00:17<00:00,  2.74it/s]
# Epoch 3: train_loss = 0.013524975627660751
# 100% 63/63 [00:01<00:00, 47.80it/s]
# Epoch 3: test_loss = 0.013526655733585358
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.984, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.954, test_mean_average_precision_at_r = 0.945
# 100% 47/47 [00:17<00:00,  2.71it/s]
# Epoch 4: train_loss = 0.013667874038219452
# 100% 63/63 [00:01<00:00, 49.21it/s]
# Epoch 4: test_loss = 0.01367327943444252
# 100% 6/6 [00:04<00:00,  1.45it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.952, test_NMI = 0.721, test_AMI = 0.718, test_r_precision = 0.929, test_mean_average_precision_at_r = 0.908
# 100% 47/47 [00:17<00:00,  2.71it/s]
# Epoch 5: train_loss = 0.013924002647399902
# 100% 63/63 [00:01<00:00, 48.62it/s]
# Epoch 5: test_loss = 3.3216617107391357
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.951, test_mean_average_precision_at_r = 0.935
# 100% 47/47 [00:17<00:00,  2.73it/s]
# Epoch 6: train_loss = 0.013946699909865856
# 100% 63/63 [00:01<00:00, 49.28it/s]
# Epoch 6: test_loss = 0.01394837349653244
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.968, test_NMI = 0.822, test_AMI = 0.820, test_r_precision = 0.950, test_mean_average_precision_at_r = 0.945
# 100% 47/47 [00:17<00:00,  2.75it/s]
# Epoch 7: train_loss = 0.013561584055423737
# 100% 63/63 [00:01<00:00, 48.85it/s]
# Epoch 7: test_loss = 0.01355014368891716
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 0.895, test_AMI = 0.894, test_r_precision = 0.978, test_mean_average_precision_at_r = 0.976
# 100% 47/47 [00:17<00:00,  2.76it/s]
# Epoch 8: train_loss = 0.013235554099082947
# 100% 63/63 [00:01<00:00, 48.45it/s]
# Epoch 8: test_loss = 3.3481462001800537
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.998, test_mean_average_precision_at_r = 0.998
# 100% 47/47 [00:17<00:00,  2.72it/s]
# Epoch 9: train_loss = 16.574190139770508
# 100% 63/63 [00:02<00:00, 27.21it/s]
# Epoch 9: test_loss = 0.013210047036409378
# 100% 6/6 [00:04<00:00,  1.46it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.989, test_mean_average_precision_at_r = 0.989
# 100% 47/47 [00:17<00:00,  2.72it/s]
# Epoch 10: train_loss = 0.02202538400888443
# 100% 63/63 [00:01<00:00, 47.58it/s]
# Epoch 10: test_loss = 0.013545066118240356
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.27it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.980, test_mean_average_precision_at_r = 0.978
# 100% 47/47 [00:17<00:00,  2.75it/s]
# Epoch 11: train_loss = 0.01297834888100624
# 100% 63/63 [00:01<00:00, 47.81it/s]
# Epoch 11: test_loss = 0.01296425610780716
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 1.000
# 100% 47/47 [00:17<00:00,  2.68it/s]
# Epoch 12: train_loss = 0.01219719648361206
# 100% 63/63 [00:01<00:00, 48.64it/s]
# Epoch 12: test_loss = 0.012180797755718231
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 1.000
# 100% 47/47 [00:18<00:00,  2.56it/s]
# Epoch 13: train_loss = 0.011525213718414307
# 100% 63/63 [00:01<00:00, 47.57it/s]
# Epoch 13: test_loss = 0.011523783206939697
# 100% 6/6 [00:04<00:00,  1.46it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 0.895, test_AMI = 0.894, test_r_precision = 0.980, test_mean_average_precision_at_r = 0.979
# 100% 47/47 [00:17<00:00,  2.76it/s]
# Epoch 14: train_loss = 0.011185023933649063
# 100% 63/63 [00:01<00:00, 49.19it/s]
# Epoch 14: test_loss = 0.011172853410243988
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.989, test_mean_average_precision_at_r = 0.988
# 100% 47/47 [00:17<00:00,  2.73it/s]
# Epoch 15: train_loss = 0.010447531938552856
# 100% 63/63 [00:01<00:00, 43.72it/s]
# Epoch 15: test_loss = 0.010426394641399384
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.999, test_mean_average_precision_at_r = 0.998
# 100% 47/47 [00:16<00:00,  2.77it/s]
# Epoch 16: train_loss = 0.00946073979139328
# 100% 63/63 [00:01<00:00, 48.82it/s]
# Epoch 16: test_loss = 0.00943814218044281
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 0.999
# 100% 47/47 [00:17<00:00,  2.76it/s]
# Epoch 17: train_loss = 0.008442044258117676
# 100% 63/63 [00:01<00:00, 46.64it/s]
# Epoch 17: test_loss = 0.008426062762737274
# 100% 6/6 [00:05<00:00,  1.18it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 1.000
# 100% 47/47 [00:17<00:00,  2.71it/s]
# Epoch 18: train_loss = 0.007531147450208664
# 100% 63/63 [00:01<00:00, 48.75it/s]
# Epoch 18: test_loss = 0.0075070299208164215
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 1.000
# 100% 47/47 [00:17<00:00,  2.72it/s]
# Epoch 19: train_loss = 0.006530914455652237
# 100% 63/63 [00:01<00:00, 48.76it/s]
# Epoch 19: test_loss = 0.006506234407424927
# 100% 6/6 [00:04<00:00,  1.46it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 1.000, test_mean_average_precision_at_r = 1.000
# 100% 47/47 [00:17<00:00,  2.73it/s]
# Epoch 20: train_loss = 0.005410125944763422
# 100% 63/63 [00:01<00:00, 48.52it/s]
# Epoch 20: test_loss = 0.005384478718042374
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.000, test_NMI = 1.000, test_AMI = 1.000, test_r_precision = 0.999, test_mean_average_precision_at_r = 0.998
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                         test_AMI ▁▆█▄█▅▆█████▆███████
# wandb:                         test_NMI ▁▆█▄█▅▆█████▆███████
# wandb:                 test_Precision@1 ▁▇▇▄█▆██████████████
# wandb: test_mean_average_precision_at_r ▁▆▇▇▇▇██████████████
# wandb:                 test_r_precision ▁▆▇▇▇▇██████████████
# wandb:                       train_loss █▄▂▂▂▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:                         val_loss █▅▂▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                         test_AMI 1.0
# wandb:                         test_NMI 1.0
# wandb:                 test_Precision@1 1.0
# wandb: test_mean_average_precision_at_r 0.99815
# wandb:                 test_r_precision 0.99937
# wandb:                       train_loss 6.15733
# wandb:                         val_loss 0.33922
# wandb:
# wandb: Synced blooming-plant-1: https://wandb.ai/insilicomab/pml-defect/runs/1jxhrgsd
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# wandb: Find logs at: ./wandb/run-20221218_154557-1jxhrgsd/logs
