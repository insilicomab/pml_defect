# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pml_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pml_defect

# %%
# !pip install -q timm wandb pytorch-metric-learning[with-hooks] torchmetrics tensorboard
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 549 kB 37.3 MB/s
#      |████████████████████████████████| 1.9 MB 69.9 MB/s
#      |████████████████████████████████| 111 kB 94.9 MB/s
#      |████████████████████████████████| 512 kB 82.8 MB/s
#      |████████████████████████████████| 182 kB 101.3 MB/s
#      |████████████████████████████████| 173 kB 75.1 MB/s
#      |████████████████████████████████| 182 kB 101.6 MB/s
#      |████████████████████████████████| 62 kB 1.4 MB/s
#      |████████████████████████████████| 168 kB 80.4 MB/s
#      |████████████████████████████████| 168 kB 109.3 MB/s
#      |████████████████████████████████| 166 kB 110.6 MB/s
#      |████████████████████████████████| 166 kB 105.6 MB/s
#      |████████████████████████████████| 162 kB 89.3 MB/s
#      |████████████████████████████████| 162 kB 103.3 MB/s
#      |████████████████████████████████| 158 kB 108.9 MB/s
#      |████████████████████████████████| 157 kB 110.9 MB/s
#      |████████████████████████████████| 157 kB 90.1 MB/s
#      |████████████████████████████████| 157 kB 88.0 MB/s
#      |████████████████████████████████| 157 kB 89.3 MB/s
#      |████████████████████████████████| 157 kB 105.6 MB/s
#      |████████████████████████████████| 157 kB 101.6 MB/s
#      |████████████████████████████████| 157 kB 88.4 MB/s
#      |████████████████████████████████| 156 kB 106.8 MB/s
#      |████████████████████████████████| 85.5 MB 119 kB/s
#   Building wheel for pathtools (setup.py) ... done
#      |████████████████████████████████| 153 kB 31.5 MB/s
#      |████████████████████████████████| 117 kB 87.4 MB/s
#      |████████████████████████████████| 79 kB 9.7 MB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !ls
# Out:
# config		 input	notebooks  sanity_test.ipynb  src     train-gpu.ipynb
# inference.ipynb  model	output	   sanity_test.py     submit  train.py

# %%
# !python sanity_test.py
# Out:
# 100% 47/47 [00:19<00:00,  2.40it/s]
# Epoch 1: train_loss = 19.17742156982422
# 100% 63/63 [00:01<00:00, 42.90it/s]
# Epoch 1: test_loss = 5.594365119934082
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.31it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9047619047619047, test_NMI = 0.5596284368914883, test_AMI = 0.5543049093822886, test_r_precision = 0.6576114890400604, test_mean_average_precision_at_r = 0.5313104852115272
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.61it/s]
# Epoch 2: train_loss = 13.687861442565918
# 100% 63/63 [00:01<00:00, 44.67it/s]
# Epoch 2: test_loss = 0.01685674861073494
# 100% 6/6 [00:04<00:00,  1.46it/s]
# 100% 2/2 [00:01<00:00,  1.26it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9841269841269841, test_NMI = 0.894880500216755, test_AMI = 0.893580407428632, test_r_precision = 0.9072467876039303, test_mean_average_precision_at_r = 0.8816790663298028
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.62it/s]
# Epoch 3: train_loss = 0.013524975627660751
# 100% 63/63 [00:01<00:00, 42.24it/s]
# Epoch 3: test_loss = 0.013526655733585358
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9841269841269841, test_NMI = 0.9999999999999987, test_AMI = 0.9999999999999987, test_r_precision = 0.9536904761904762, test_mean_average_precision_at_r = 0.9447399628715258
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.63it/s]
# Epoch 4: train_loss = 0.013667874038219452
# 100% 63/63 [00:01<00:00, 44.00it/s]
# Epoch 4: test_loss = 0.01367327943444252
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9523809523809523, test_NMI = 0.721453616533145, test_AMI = 0.7180467300130704, test_r_precision = 0.9292044595616022, test_mean_average_precision_at_r = 0.9079375260264301
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.62it/s]
# Epoch 5: train_loss = 0.013924002647399902
# 100% 63/63 [00:01<00:00, 43.38it/s]
# Epoch 5: test_loss = 3.3216617107391357
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0, test_NMI = 0.9999999999999987, test_AMI = 0.9999999999999987, test_r_precision = 0.9505026455026454, test_mean_average_precision_at_r = 0.9353514599308895
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.62it/s]
# Epoch 6: train_loss = 0.013946699909865856
# 100% 63/63 [00:01<00:00, 44.51it/s]
# Epoch 6: test_loss = 0.01394837349653244
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.31it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9682539682539681, test_NMI = 0.8217874380851424, test_AMI = 0.8195679158589326, test_r_precision = 0.9500755857898714, test_mean_average_precision_at_r = 0.9445226197664386
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.66it/s]
# Epoch 7: train_loss = 0.013561584055423737
# 100% 63/63 [00:01<00:00, 42.99it/s]
# Epoch 7: test_loss = 0.01355014368891716
# 100% 6/6 [00:04<00:00,  1.49it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0, test_NMI = 0.894880500216755, test_AMI = 0.893580407428632, test_r_precision = 0.978318216175359, test_mean_average_precision_at_r = 0.9761631076781722
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.66it/s]
# Epoch 8: train_loss = 0.013235554099082947
# 100% 63/63 [00:01<00:00, 44.10it/s]
# Epoch 8: test_loss = 3.3481462001800537
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.30it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0, test_NMI = 0.9999999999999987, test_AMI = 0.9999999999999987, test_r_precision = 0.9980158730158729, test_mean_average_precision_at_r = 0.9975649614565986
#
#
#
#
# 100% 47/47 [00:17<00:00,  2.62it/s]
# Epoch 9: train_loss = 16.574190139770508
# 100% 63/63 [00:01<00:00, 42.00it/s]
# Epoch 9: test_loss = 0.013210047036409378
# 100% 6/6 [00:04<00:00,  1.47it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0, test_NMI = 0.9999999999999987, test_AMI = 0.9999999999999987, test_r_precision = 0.9893235071806499, test_mean_average_precision_at_r = 0.9886064654246247
#
#
#
#
# 100% 47/47 [00:18<00:00,  2.59it/s]
# Epoch 10: train_loss = 0.02202538400888443
# 100% 63/63 [00:01<00:00, 45.10it/s]
# Epoch 10: test_loss = 0.013545066118240356
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.27it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0, test_NMI = 0.9999999999999987, test_AMI = 0.9999999999999987, test_r_precision = 0.9800529100529101, test_mean_average_precision_at_r = 0.9775987829990201
