# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pml_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pml_defect

# %%
# !pip install -q timm wandb pytorch-metric-learning[with-hooks] torchmetrics tensorboard
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 549 kB 4.7 MB/s
#      |████████████████████████████████| 1.9 MB 86.6 MB/s
#      |████████████████████████████████| 111 kB 91.8 MB/s
#      |████████████████████████████████| 512 kB 82.6 MB/s
#      |████████████████████████████████| 182 kB 96.2 MB/s
#      |████████████████████████████████| 182 kB 79.7 MB/s
#      |████████████████████████████████| 173 kB 85.9 MB/s
#      |████████████████████████████████| 62 kB 1.5 MB/s
#      |████████████████████████████████| 168 kB 101.6 MB/s
#      |████████████████████████████████| 168 kB 82.1 MB/s
#      |████████████████████████████████| 166 kB 86.7 MB/s
#      |████████████████████████████████| 166 kB 87.1 MB/s
#      |████████████████████████████████| 162 kB 97.7 MB/s
#      |████████████████████████████████| 162 kB 105.3 MB/s
#      |████████████████████████████████| 158 kB 73.3 MB/s
#      |████████████████████████████████| 157 kB 89.2 MB/s
#      |████████████████████████████████| 157 kB 119.6 MB/s
#      |████████████████████████████████| 157 kB 86.3 MB/s
#      |████████████████████████████████| 157 kB 106.9 MB/s
#      |████████████████████████████████| 157 kB 103.5 MB/s
#      |████████████████████████████████| 157 kB 105.1 MB/s
#      |████████████████████████████████| 157 kB 103.5 MB/s
#      |████████████████████████████████| 156 kB 97.9 MB/s
#      |████████████████████████████████| 85.5 MB 1.1 MB/s
#   Building wheel for pathtools (setup.py) ... done
#      |████████████████████████████████| 153 kB 4.9 MB/s
#      |████████████████████████████████| 117 kB 45.3 MB/s
#      |████████████████████████████████| 79 kB 208 kB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !ls
# Out:
# config		 input	notebooks  sanity_test.ipynb  src     train-gpu.ipynb
# inference.ipynb  model	output	   sanity_test.py     submit  train.py

# %%
# !python sanity_test.py
# Out:
# 100% 47/47 [00:18<00:00,  2.52it/s]
# Epoch 1: train_loss = 19.17742156982422
# 100% 63/63 [00:01<00:00, 48.86it/s]
# Epoch 1: test_loss = 5.594365119934082
# 100% 6/6 [00:04<00:00,  1.48it/s]
# 100% 2/2 [00:01<00:00,  1.29it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9048, test_NMI = 0.5596, test_AMI = 0.5543, test_r_precision = 0.6576, test_mean_average_precision_at_r = 0.5313
# 100% 47/47 [00:17<00:00,  2.69it/s]
# Epoch 2: train_loss = 13.687861442565918
# 100% 63/63 [00:01<00:00, 47.28it/s]
# Epoch 2: test_loss = 0.01685674861073494
# 100% 6/6 [00:04<00:00,  1.44it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9841, test_NMI = 0.8949, test_AMI = 0.8936, test_r_precision = 0.9072, test_mean_average_precision_at_r = 0.8817
# 100% 47/47 [00:17<00:00,  2.69it/s]
# Epoch 3: train_loss = 0.013524975627660751
# 100% 63/63 [00:01<00:00, 46.18it/s]
# Epoch 3: test_loss = 0.013526655733585358
# 100% 6/6 [00:04<00:00,  1.43it/s]
# 100% 2/2 [00:01<00:00,  1.28it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9841, test_NMI = 1.0000, test_AMI = 1.0000, test_r_precision = 0.9537, test_mean_average_precision_at_r = 0.9447
# 100% 47/47 [00:17<00:00,  2.72it/s]
# Epoch 4: train_loss = 0.013667874038219452
# 100% 63/63 [00:01<00:00, 46.67it/s]
# Epoch 4: test_loss = 0.01367327943444252
# 100% 6/6 [00:04<00:00,  1.45it/s]
# 100% 2/2 [00:01<00:00,  1.26it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9524, test_NMI = 0.7215, test_AMI = 0.7180, test_r_precision = 0.9292, test_mean_average_precision_at_r = 0.9079
# 100% 47/47 [00:17<00:00,  2.74it/s]
# Epoch 5: train_loss = 0.013924002647399902
# 100% 63/63 [00:01<00:00, 47.74it/s]
# Epoch 5: test_loss = 3.3216617107391357
# 100% 6/6 [00:04<00:00,  1.44it/s]
# 100% 2/2 [00:01<00:00,  1.26it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0000, test_NMI = 1.0000, test_AMI = 1.0000, test_r_precision = 0.9505, test_mean_average_precision_at_r = 0.9354
# 100% 47/47 [00:18<00:00,  2.57it/s]
# Epoch 6: train_loss = 0.013946699909865856
# 100% 63/63 [00:01<00:00, 46.92it/s]
# Epoch 6: test_loss = 0.01394837349653244
# 100% 6/6 [00:04<00:00,  1.45it/s]
# 100% 2/2 [00:01<00:00,  1.27it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 0.9683, test_NMI = 0.8218, test_AMI = 0.8196, test_r_precision = 0.9501, test_mean_average_precision_at_r = 0.9445
# 100% 47/47 [00:17<00:00,  2.76it/s]
# Epoch 7: train_loss = 0.013561584055423737
# 100% 63/63 [00:01<00:00, 45.31it/s]
# Epoch 7: test_loss = 0.01355014368891716
# 100% 6/6 [00:04<00:00,  1.44it/s]
# 100% 2/2 [00:01<00:00,  1.24it/s]
# WARNING clustering 63 points to 2 centroids: please provide at least 78 training points
# Computing accuracy
# test_Precision@1 = 1.0000, test_NMI = 0.8949, test_AMI = 0.8936, test_r_precision = 0.9783, test_mean_average_precision_at_r = 0.9762
#  43% 20/47 [00:07<00:09,  2.79it/s]
